# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_excel("total_data.xls")
df.insert(1, '类别代号', 0)

for i in range(2023):
    if('特殊膳食' in df.iloc[i, 2]):
        df.iloc[i, 1] = 1
        
    elif('乳及其乳制品' in df.iloc[i, 2]):
        df.iloc[i, 1] = 2
        
    elif('饮料' in df.iloc[i, 2]):
        df.iloc[i, 1] = 3
        
    elif('粮食及其制品' in df.iloc[i, 2]):
        df.iloc[i, 1] = 4
        
    elif('食用油脂' in df.iloc[i, 2]):
        df.iloc[i, 1] = 5
        
    elif('调味品' in df.iloc[i, 2]):
        df.iloc[i, 1] = 6
        
    elif('肉制品' in df.iloc[i, 2]):
        df.iloc[i, 1] = 7
        
    elif('方便食品' in df.iloc[i, 2]):
        df.iloc[i, 1] = 8
        
    elif('罐头' in df.iloc[i, 2]):
        df.iloc[i, 1] = 9
        
    elif('冷冻饮品' in df.iloc[i, 2]):
        df.iloc[i, 1] = 10
        
    elif('速冻食品' in df.iloc[i, 2]):
        df.iloc[i, 1] = 11
        
    elif('薯类和膨化食品' in df.iloc[i, 2]):
        df.iloc[i, 1] = 12
        
    elif('糖果' in df.iloc[i, 2]):
        df.iloc[i, 1] = 13
        
    elif('茶叶' in df.iloc[i, 2]):
        df.iloc[i, 1] = 14
    
    elif('酒类' in df.iloc[i, 2]):
        df.iloc[i, 1] = 15
    
    elif('蔬菜' in df.iloc[i, 2]):
        df.iloc[i, 1] = 16
        
    elif('水果' in df.iloc[i, 2]):
        df.iloc[i, 1] = 17
        
    elif('炒货' in df.iloc[i, 2]):
        df.iloc[i, 1] = 18
    
    elif('蛋' in df.iloc[i, 2]):
        df.iloc[i, 1] = 19
        
    elif('可可' in df.iloc[i, 2]):
        df.iloc[i, 1] = 20
        
    elif('食糖' in df.iloc[i, 2]):
        df.iloc[i, 1] = 21
        
    elif('水产' in df.iloc[i, 2]):
        df.iloc[i, 1] = 22
        
    elif('淀粉' in df.iloc[i, 2]):
        df.iloc[i, 1] = 23
    
    elif('焙烤产品' in df.iloc[i, 2]):
        df.iloc[i, 1] = 24
        
    elif('豆及其豆制品' in df.iloc[i, 2]):
        df.iloc[i, 1] = 25
        
    elif('蜂产品' in df.iloc[i, 2]):
        df.iloc[i, 1] = 26
        
    elif('保健食品' in df.iloc[i, 2]):
        df.iloc[i, 1] = 27
        
    elif('食品添加剂' in df.iloc[i, 2]):
        df.iloc[i, 1] = 28
        
    elif('食品相关产品' in df.iloc[i, 2]):
        df.iloc[i, 1] = 29
        
    elif('化妆品' in df.iloc[i, 2]):
        df.iloc[i, 1] = 30
        
    elif('餐饮环节产品' in df.iloc[i, 2]):
        df.iloc[i, 1] = 31
    
    else:
        df.iloc[i, 1] = 32

# %%
df.insert(25, '抽检代码', 0)

for i in range(2023):
    if('国抽' in df.iloc[i, 26]):
        df.iloc[i, 25] = 1
    elif('省抽' in df.iloc[i, 26]):
        df.iloc[i, 25] = 2
    elif('市抽' in df.iloc[i, 26]):
        df.iloc[i, 25] = 3

        
df.insert(15, '生产省份代码', 0)

for i in range(2023):
    if(df.iloc[i, 16] == '广东'):
        df.iloc[i, 15] = 1
    elif(df.iloc[i, 16] == '山东'):
        df.iloc[i, 15] = 2
    elif(df.iloc[i, 16] == '江苏'):
        df.iloc[i, 15] = 3
    elif(df.iloc[i, 16] == '河南'):
        df.iloc[i, 15] = 4
    elif(df.iloc[i, 16] == '河北'):
        df.iloc[i, 15] = 5
    elif(df.iloc[i, 16] == '上海'):
        df.iloc[i, 15] = 6
    elif(df.iloc[i, 16] == '浙江'):
        df.iloc[i, 15] = 7
    elif(df.iloc[i, 16] == '陕西'):
        df.iloc[i, 15] = 8
    elif(df.iloc[i, 16] == '湖南'):
        df.iloc[i, 15] = 9
    elif(df.iloc[i, 16] == '重庆'):
        df.iloc[i, 15] = 10
    elif(df.iloc[i, 16] == '福建'):
        df.iloc[i, 15] = 11
    elif(df.iloc[i, 16] == '天津'):
        df.iloc[i, 15] = 12
    elif(df.iloc[i, 16] == '云南'):
        df.iloc[i, 15] = 13
    elif(df.iloc[i, 16] == '四川'):
        df.iloc[i, 15] = 14
    elif(df.iloc[i, 16] == '广西'):
        df.iloc[i, 15] = 15
    elif(df.iloc[i, 16] == '安徽'):
        df.iloc[i, 15] = 16
    elif(df.iloc[i, 16] == '海南'):
        df.iloc[i, 15] = 17
    elif(df.iloc[i, 16] == '江西'):
        df.iloc[i, 15] = 18
    elif(df.iloc[i, 16] == '湖北'):
        df.iloc[i, 15] = 19
    elif(df.iloc[i, 16] == '山西'):
        df.iloc[i, 15] = 20
    elif(df.iloc[i, 16] == '辽宁'):
        df.iloc[i, 15] = 21
    elif(df.iloc[i, 16] == '黑龙江'):
        df.iloc[i, 15] = 22
    elif(df.iloc[i, 16] == '内蒙古'):
        df.iloc[i, 15] = 23
    elif(df.iloc[i, 16] == '新疆'):
        df.iloc[i, 15] = 24
    elif(df.iloc[i, 16] == '甘肃'):
        df.iloc[i, 15] = 25
    elif(df.iloc[i, 16] == '青海'):
        df.iloc[i, 15] = 26
    elif(df.iloc[i, 16] == '贵州'):
        df.iloc[i, 15] = 27
    elif(df.iloc[i, 16] == '吉林'):
        df.iloc[i, 15] = 28
    elif(df.iloc[i, 16] == '宁夏'):
        df.iloc[i, 15] = 29
        
df.insert(18, '抽样单位代码', 0)

# %%
area_data = {
        '北京': ['北京','朝阳区', '海淀区', '通州区', '房山区', '丰台区', '昌平区', '大兴区', '顺义区', '西城区', '延庆县', '石景山区', '宣武区', '怀柔区', '崇文区', '密云县',
               '东城区', '门头沟区', '平谷区'],
        '广东':['广东', '龙门', '和平', '连平', '霞山', '连山', '连南', '台山', '恩平', '鹤山', '龙川', '廉江', '乐昌', '罗定', '东源', '四会', '东莞', '广州', '中山', '深圳', '惠州', '江门', '珠海', '汕头', '佛山', '湛江', '河源', '紫金', '肇庆','潮州', '清远', '佛冈', '阳山', '清新', '韶关', '新丰', '揭阳', '阳江', '云浮', '郁南', '茂名', '电白', '化州', '梅州', '汕尾'],
        '山东':['山东', '冠县', '莒南', '荣成', '济南', '济阳', '青岛', '崂山', '临沂', '济宁', '菏泽', '烟台','泰安', '淄博', '潍坊', '日照', '威海', '滨州', '东营', '聊城', '德州', '莱芜', '枣庄'],
        '江苏':['江苏', '六套', '苏州', '徐州', '盐城', '无锡','南京', '南通', '连云', '常州', '扬州', '镇江', '淮安', '泰州', '宿迁'],
        '河南':['河南', '孟州', '商城', '社旗', '中牟', '汝州', '淇滨', '郑州', '南阳', '新乡', '安阳', '洛阳', '信阳','平顶', '周口', '商丘', '开封', '焦作', '解放', '驻马', '濮阳', '三门', '漯河', '许昌', '鹤壁', '济源'],
        '上海':['上海', '松江区', '宝山区', '金山区','嘉定区', '南汇区', '青浦区', '浦东新区', '奉贤区', '闵行区', '徐汇区', '静安区', '黄浦区', '普陀区', '杨浦区', '虹口区', '闸北区', '长宁区', '崇明县', '卢湾区'],
        '河北':[ '河北', '石家', '唐山', '保定', '邯郸', '邢台', '河北区', '沧州', '秦皇岛', '张家', '衡水', '廊坊', '承德'],
        '浙江':['浙江', '温州', '宁波','杭州', '台州', '嘉兴', '金华', '湖州', '绍兴', '舟山', '丽水', '衢州'],
        '陕西':['陕西', '西安', '咸阳', '宝鸡', '汉中', '渭南','安康', '榆林', '商洛', '延安', '铜川'],
        '湖南':[ '湖南', '长沙', '邵阳', '常德', '衡阳', '株洲', '湘潭', '永州', '岳阳', '怀化', '郴州','娄底', '益阳', '张家', '湘西'],
        '重庆':[  '重庆', '江北区', '渝北区', '沙坪坝区', '九龙坡区', '万州区', '永川市', '南岸区', '酉阳县', '北碚区', '涪陵区', '秀山县', '巴南区', '渝中区', '石柱县', '忠县', '合川市', '大渡口区', '开县', '长寿区', '荣昌县', '云阳县', '梁平县', '潼南县', '江津市', '彭水县', '璧山县', '綦江县',
     '大足县', '黔江区', '巫溪县', '巫山县', '垫江县', '丰都县', '武隆县', '万盛区', '铜梁县', '南川市', '奉节县', '双桥区', '城口县'],
        '福建':['福建', '漳州', '泉州','厦门', '福州', '莆田', '宁德', '三明', '南平', '龙岩'],
        '天津':['天津', '和平区', '北辰区', '河北区', '河西区', '西青区', '津南区', '东丽区', '武清区','宝坻区', '红桥区', '大港区', '汉沽区', '静海县', '宁河县', '塘沽区', '蓟县', '南开区', '河东区'],
        '云南':[ '云南', '昆明', '红河', '大理', '文山', '德宏', '曲靖', '昭雄', '楚雄', '保山', '玉溪', '丽江', '临沧', '思茅', '西双', '怒江', '迪庆'],
        '四川':['四川', '成都', '绵阳', '广元', '苍溪', '达州', '南充', '德阳', '广安', '阿坝', '巴中', '遂宁', '内江', '凉山', '攀枝', '乐山', '自贡', '泸州', '雅安', '宜宾', '资阳','眉山', '甘孜'],
        '广西':['广西', '扶绥', '陆川', '宾阳', '桂平', '贵港', '平南', '玉林', '北流', '博白', '兴业', '北海', '南宁', '柳州', '鹿寨', '融安', '桂林', '阳朔', '锦绣', '梧州', '钦州', '来宾', '河池', '百色', '贺州', '崇左',  '防城'],
        '安徽':['安徽', '芜湖', '合肥', '六安', '宿州', '阜阳','安庆', '马鞍', '蚌埠', '淮北', '淮南', '宣城', '黄山', '铜陵', '亳州','池州', '巢湖', '滁州'],
        '海南':['海南', '三亚', '海口', '琼海', '文昌', '东方', '昌江', '陵水', '乐东', '五指山', '保亭', '澄迈', '万宁','儋州', '临高', '白沙', '定安', '琼中', '屯昌'],
        '江西':['江西', '南昌', '赣州', '上饶', '吉安', '九江', '新余', '抚州', '宜春', '景德', '萍乡市', '鹰潭'],
        '湖北':['湖北', '武汉', '宜昌', '襄樊', '荆州', '恩施', '孝感', '黄冈', '十堰', '咸宁', '黄石', '铁山', '仙桃', '随州', '天门', '荆门', '潜江', '鄂州', '神农'],
        '山西':['山西', '河津', '曲沃', '太原', '大同', '运城', '长治', '晋城', '忻州', '临汾', '吕梁', '晋中', '阳泉', '朔州'],
        '辽宁':['辽宁', '大连', '沈阳', '丹东', '辽阳', '葫芦', '锦州', '朝阳', '营口', '鞍山', '抚顺', '阜新', '本溪', '盘锦', '铁岭'],
        '黑龙江':['黑龙', '齐齐', '哈尔', '大庆', '佳木', '双鸭', '牡丹', '鸡西','黑河', '绥化', '鹤岗', '伊春', '大兴', '七台'],
        '内蒙古':['内蒙', '赤峰', '包头', '通辽', '呼和', '乌海', '鄂尔', '呼伦','兴安', '巴彦', '乌兰', '锡林', '阿拉'],
        '贵州':['贵州', '沿河', '贵阳', '黔东', '黔南', '遵义', '黔西', '毕节', '铜仁','安顺', '六盘'],
        '甘肃':['甘肃', '兰州', '天水', '庆阳', '武威', '酒泉', '张掖', '陇南', '白银', '定西', '平凉', '嘉峪', '临夏','金昌', '甘南'],
        '青海':['青海', '西宁', '海西', '海东', '海北', '果洛', '玉树', '黄南'],
        '新疆':['新疆','新疆维吾尔自治区', '乌鲁', '伊犁', '昌吉','石河', '哈密', '阿克', '巴音', '喀什', '克拉', '和田', '阿勒', '吐鲁', '阿拉', '博尔', '五家',
     '克孜', '图木'],
        '吉林':['吉林', '吉林', '长春', '白山', '白城','延边', '松原', '辽源', '通化', '四平'],
        '宁夏':['宁夏', '银川', '吴忠', '中卫', '石嘴山', '固原']
}

for i in range(2023):
    if(type(df.iloc[i, 19]) == str):
        if(df.iloc[i, 19][:2] in area_data['山东']):
            df.iloc[i, 18] = 2
        elif(df.iloc[i, 19][:2] in area_data['广东']):
            df.iloc[i, 18] = 1
        elif(df.iloc[i, 19][:2] in area_data['江苏']):
            df.iloc[i, 18] = 3
        elif(df.iloc[i, 19][:2] in area_data['河南']):
            df.iloc[i, 18] = 4
        elif(df.iloc[i, 19][:2] in area_data['上海']):
            df.iloc[i, 18] = 6
        elif(df.iloc[i, 19][:2] in area_data['河北']):
            df.iloc[i, 18] = 5
        elif(df.iloc[i, 19][:2] in area_data['浙江']):
            df.iloc[i, 18] = 7
        elif(df.iloc[i, 19][:2] in area_data['陕西']):
            df.iloc[i, 18] = 8
        elif(df.iloc[i, 19][:2] in area_data['湖南']):
            df.iloc[i, 18] = 9
        elif(df.iloc[i, 19][:2] in area_data['重庆']):
            df.iloc[i, 18] = 10
        elif(df.iloc[i, 19][:2] in area_data['福建']):
            df.iloc[i, 18] = 11
        elif(df.iloc[i, 19][:2] in area_data['天津']):
            df.iloc[i, 18] = 12
        elif(df.iloc[i, 19][:2] in area_data['云南']):
            df.iloc[i, 18] = 13
        elif(df.iloc[i, 19][:2] in area_data['四川']):
            df.iloc[i, 18] = 14
        elif(df.iloc[i, 19][:2] in area_data['广西']):
            df.iloc[i, 18] = 15
        elif(df.iloc[i, 19][:2] in area_data['安徽']):
            df.iloc[i, 18] = 16
        elif(df.iloc[i, 19][:2] in area_data['海南']):
            df.iloc[i, 18] = 17
        elif(df.iloc[i, 19][:2] in area_data['江西']):
            df.iloc[i, 18] = 18
        elif(df.iloc[i, 19][:2] in area_data['湖北']):
            df.iloc[i, 18] = 19
        elif(df.iloc[i, 19][:2] in area_data['山西']):
            df.iloc[i, 18] = 20
        elif(df.iloc[i, 19][:2] in area_data['辽宁']):
            df.iloc[i, 18] = 21
        elif(df.iloc[i, 19][:2] in area_data['黑龙江']):
            df.iloc[i, 18] = 22
        elif(df.iloc[i, 19][:2] in area_data['内蒙古']):
            df.iloc[i, 18] = 23
        elif(df.iloc[i, 19][:2] in area_data['新疆']):
            df.iloc[i, 18] = 24
        elif(df.iloc[i, 19][:2] in area_data['甘肃']):
            df.iloc[i, 18] = 25
        elif(df.iloc[i, 19][:2] in area_data['青海']):
            df.iloc[i, 18] = 26
        elif(df.iloc[i, 19][:2] in area_data['贵州']):
            df.iloc[i, 18] = 27
        elif(df.iloc[i, 19][:2] in area_data['吉林']):
            df.iloc[i, 18] = 28
        elif(df.iloc[i, 19][:2] in area_data['宁夏']):
            df.iloc[i, 18] = 29
        elif(df.iloc[i, 19][:2] in area_data['北京']):
            df.iloc[i, 18] = 30

# %%
// 检查遗漏项
for i in range(2023):
    if(type(df.iloc[i, 19]) == str and df.iloc[i, 18] == 0):
        print(df.iloc[i, 19])
# Out:
# /
# 隆林各族自治县新州镇新兴街72号一楼门面
# 兰考县城区兰曹路南侧
# 武陟县文化路中段
# 温县黄河街道盐东村一排路西2号
# 乳源县乳城镇北环中路9号中国供销粤北农特产品电商物流商贸城13栋-13-（52-61）-1、14栋14-（21、23-34）-1号商铺
# 永城市商务中心区欧亚路175号（地下负一层）
# 张夏镇张夏村中街南
# 英德市英城和平南路96号
# 蓝田县北环路西段
# 原阳县福宁集镇东庄村
# 新兴县河头镇河头圩
# 怀集县诗洞镇府前路邮政储蓄左侧
# 怀集县蓝钟镇派出所左侧（姚高强房屋）
# 封开县罗董镇罗董村委会留村村(住改商)
# 德庆县凤村镇始兴路（何兰洲宅）
# 新兴县天堂镇东震路口（郑北金房屋）
# 中国(河南)自由贸易试验区洛阳片区张庄社区“邻里铺子”E03
# 鹿邑县赵村乡赵东311国道南
# 新密市大楼集贸市场
# 宛城区五里堡办事处苏庄
# /
# 海宁市袁花富强食品厂
# 项城市东方康龙食品加工厂
# 昭平县走马镇西坪村西坪街（商住区）
# 西峡县回车镇杜店村
# 新野县汉华街道办事处西环路北段西侧
# 南召县小店乡川店村
# 唐河县滨河街道办事处龙山路中段
# 草庙子镇红绿灯南
# 内乡县城关镇县衙东路古衙360商业街一楼2号
# 合浦县石湾镇永康居委会八队新建街22号
# 博颂路与索凌路交叉口向东100米路南庙李综合市场内7号商铺
# 博颂路与索凌路交叉口向东100米路南庙李综合市场内7号商铺
# 东海县温泉镇驻地东海县千庄商贸有限公司温泉生活广场分公司（一层西南侧、二楼整层）
# 茌平县温陈乡许刘村丁块街
# 宁陵县柳河镇黄河路东段路北29号
# 封丘县留光镇留光村
# 上林县明亮镇亭亮社区新市场
# 凤山县凤城镇巴烈开发区京乐路
# 凭祥市北大路三支2巷2号旁
# 宁明县亭亮新街325号
# 横县云表镇云峰街生活市场旁（冯富杰出租房）
# 横县峦城镇商贸街98号
# 安岳县岳阳镇柠都大道152号-1F
# /
# /
# 贵宇集贸市场
# 容县容州镇国中路397号
# 高州市平山镇大仁庙圩（李增武屋）（信息申报制）
# 北京市顺义区石园北区农副产品批发市场内东43号
# 溧阳市社渚镇农贸市场内
# 凭祥市夏石镇西门街27号
# 乳源县乳城镇解放中路建筑公司办公楼首层靠南面第二间商铺
# 高州市东岸镇东岸圩横圩（彭安进屋）
# 滕州市东郭镇后村（后街路西）
# 山心镇蓉南路
# 绵竹市九龙镇蜀熙街
# 北京市门头沟区双峪农副产品批发市场北房14号
# 陆丰市南塘镇人民南路21号
# 隰县古桥东117号
# 北京市大兴区天堂河市场南排26号
# 海安市高新区永安北路48号1幢
# 乡宁县昌宁镇文家湾小区一楼门面房
# 乡宁县昌宁镇文家湾小区门面房
# 阳谷县万达综合市场
# 溧阳市社渚镇农贸市场内
# 北京市顺义区临空经济核心区安宁街7号院7号楼1层103号
# 惠东县梁化镇梁燕公路楼阁村11号
# 惠东县梁化镇光长村梁燕公路边
# 淇县西岗镇西岗村西头
# 吴川市塘尾街道边坡社区冷冻厂旁边
# 北京市海淀区亮甲店常旺村1号亮甲店菜市场中心16号
# 北京市朝阳区孙河乡康营家园KY29区HIR号楼1层102A
# 班玛县赛来塘人民路238号
# 郯城县港上镇驻地
# 惠东县白花镇联进加油站对面
# 北京市延庆区延庆镇自由街西街11号
# 田林县乐里镇绕城路富丽小区（自有铺面）
# 平乐县二塘镇中兴街297号
# 盂县秀水镇高城首府
# 徐闻县徐城城墙路45号
# 徐闻县龙塘镇新街
# 宛城区红泥湾镇红茶路南段路西60号
# 东海县温泉镇驻地东海县千庄商贸有限公司温泉生活广场分公司（一层西南侧、二楼整层）
# 新兴县河头镇楼下村委会湾边村湾边街练惠来房屋
# /
# 松旺林业站一楼
# 东阿县文化街与青年街交叉口西北角
# /
# /
# 鹿邑县赵村乡赵东311国道南
# 长垣县樊相镇商业街158号
# 郸城县胡集供销社
# 英德市大站镇广场南侧C栋-2号
# 英德市九龙镇九沙路
# 示范区黄河大街北段鼎立国际城28号楼102室
# 通许县四所楼镇四所楼东
# 禹土台区融园景园3号楼01号
# 惠阳区平潭镇光辉村委会乌塘村48号
# 博罗县罗阳镇新世纪市场7号楼12号
# 九台市南山街南部新城区商贸城15号楼
# 英德市黄花镇荣盛大街19号
# 连州市连州镇谢屋路9号一楼
# 英德市黄花镇明迳街80号
# 槐荫区腊山北路6号
# /
# 红旗大街北礼贤路南
# 北京市怀柔区运通盛世农副产品市场内西大厅1、2、3号
# 深州市前磨头镇前磨头村34号
# 新都区龙桥镇龙桥市场84号
# 尤溪县城关镇闽中大道2号1-4层
# 汇川区钦州路汇宏农贸市场4号（摊）
# 北京市东城区东四北大街257号
# 荥经县严道镇同心上街18号内B-25号（农贸市场内）
# 平果铝桥市场38号门面
# 槐荫段店村91号南排24号
# 天桥区清河农贸市场
# 历下区按察司街72号
# 岑溪市玉梧大道296号
# 苍梧县石桥镇旧街44号李炳权出租屋
# 苍梧县旺甫镇浔阳路216号
# 公安县斗湖堤镇荆江河路
# 惠东县梁化镇晨光村八队
# 惠东县梁化镇黎光村十一队
# 惠东县梁化镇黎光村十一队
# 靖西市新靖镇龙潭新区湿地公园周边A地块靖西环球大酒店第二层
# 元江县甘庄街道办振兴街
# 横县那阳镇那阳新街自有屋
# 横县百合镇黄村上黄片第五号铺面
# 横县百合镇黄村新市场路口（李荣坚自有屋）
# 横县横州镇大桥头（谢世国自有屋）
# /
# /
# 合山市里兰商业街15号
# 象州县象州镇文明路49号
# 忻城县红渡镇红渡农贸市场上忻路15号
# 平乐县平乐镇东泉街59号
# 上杭县官庄畲族乡回龙村兴龙街39号
# 平阴县 城黄河 市场
# /
# 东川区桂苑街北段
# 东川区集义农贸市场
# 泰山区邱家店镇文化站西邻
# 北京市延庆区延庆镇广兴街路东(广兴街76号)
# 覃塘区大岭乡木马路6号
# 覃塘区大岭乡木马路6号
# 中国（湖北)自贸区宜昌市伍家岗区三峡物流园D1-1021-1024号
# 覃塘区东龙镇富力新区13栋567号
# 覃塘区东龙镇龙翔小区
# 沙市区两湖市场千货A区46-49号
# 沙市区两湖市场千货A区46-49号
# 罗城仫佬族自治县公园路1号
# 天峨县六排镇农贸街40号9（左边）
# 容县松山镇儒地村大山口队
# 西埌镇新民街
# 容县石头镇石头村大桥队自屋
# 东城南街
# 蒙山县陈塘镇陈塘街86号
# 岑溪市马路镇马路社区石兴街10号
# 岑溪市大隆镇大隆街
# 岑溪市大隆镇大隆街
# 子长县南门
# 新泰市新甫路中段路南
# 岑溪市岑城镇解放大道65号
# 卧龙区人民路与范蠡路交叉口东北角二楼
# 新蔡县李桥镇新华书店东侧
# 北京市朝阳区望京路4号8号楼6层613室
# 新蔡县古吕街道人民路中段路北（建行对面）
# 滑县道口镇道城路中段路南新华路路口
# 南部县大桥镇
# 北京市平谷区迎宾街1号院22号楼五层F5-01
# https://diyidian.jd.com/
# 阆中市沙溪办事处金鼓村
# 青山湖区京东镇塘南村淦村105号店面
# http://i.waimai.meituan.com/external/food/519064981791653/500413108?utm_source=appshare&amp;amp;utm_fromapp=qq
# https://item.jd.com/31844933544.html
# 准格尔旗薛家湾镇开源南路
# 海城市腾鳌镇北石桥村
# 宁江区团结街
# 宁江区团结街
# 如皋市如城街道中山路与益寿路交界处万都广场南区B3一层、二层
# https://qiaoxianggesp.tmall.com/?spm=a1z10.5-b-s.1997427721.d4918089.282d49adpvWlrr
# https://cythcpsp.tmall.com/?spm=a220o.1000855.1997427721.d4918089.47a36092dMiRHO
# https://keyisp.tmall.com/?spm=a1z10.3-b.1997427721.d4918089.462d41e1Ooj0Bp
# http://i.waimai.meituan.com/external/food/339805932163120/147770802?utm_source=appshare&amp;amp;utm_fromapp=qq
# https://yitaosp.tmall.com/
# 安陆市金秋大道北路77号金秋御园一楼
# 当阳市玉阳办事处长板路（金叶小区）
# 成武县先农坛街中段路南（成武县国税局西50米）
# 潍城区北宫西街239号
# 兰西县新立社区天翔购物广场负一层
# 海淀区学院南路17号门面房西侧1、2、3层
# 北京市丰台区顺八条8号院三区3号楼-1层-101-01、-02
# 邹城市峄山镇贾洼村104国道西（峄山镇工业园）
# https://item.taobao.com/item.htm?spm=a1z09.2.0.0.34a82e8dar5b1k&amp;amp;amp;id=547707767259&amp;amp;amp;_u=m25rr7635732
# 如皋市如城街道中山路与益寿路交界处万都广场南区B3一层、二层
# https://www.amazon.cn/gp/product/B078X4LWB4/ref=oh_aui_detailpage_o01_s00?ie=UTF8&amp;psc=1
# 青山湖区青山湖北大道涂黄村二期农民公寓祥和花园店面以南3号店
# 北京市房山区石楼镇石楼村石楼大街37号
# 安陆市碧涢路170号
# 白桥路与练江路交叉口西南角
# 泌水街道办事处行政路西段（老官庄路口）
# 橡林街道张楼张西市场
# 纬一路西段南侧
# 回郭镇大街
# 莲花路
# 八一路东侧
# 芝田镇芝田村
# 沈丘县槐店镇泰安东路
# 陈州路东段
# 郫县犀浦镇龙吟路230号合能.四季城8号楼1-2层
# 中原路181号黎明大厦一楼门面房
# 东城区芒山路南段永宿路口
# 青原区和气路西侧
# 敦化市渤海街紫钰家园C区
# 延津县王楼乡草店村
# 江陵县三湖管理区工业园区发展大道
# 谷城县庙滩镇夕照街社区十八组
# 浠水县清泉镇云路口社区五组
# （湖北省襄阳市）保康县城关镇夹堤巷41号
# （湖北省襄阳市）保康县城关镇夹堤巷41号
# https://detail.tmall.com/item.htm?spm=a1z10.3-b.w4011-9954602491.40.eprSv4&id=43783294783&rn=fc765c3771c76cf5ed824d520811f378&abbucket=1&skuId=3117928162137
# 松滋市卸甲坪土家族乡曲尺河村四组
# 松滋市卸甲坪土家族乡曲尺河村四组
# 双峰县工业科技园
# 北京市朝阳区朝阳路太平庄176号
# 英德市大洞镇桥头
# 莲塘镇下市路
# 莒县刘官庄镇后沙岭村

# %%
df.to_csv("final.csv")
